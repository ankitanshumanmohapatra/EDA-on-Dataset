# %% [markdown]
# #Ankit Anshuman Mohapatra
# #2006006
# #IRIS DATASET

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes #gives data types
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
#MATPLOTLIB
import matplotlib.pyplot as plt
# %matplotlib inline
#seaborn
import seaborn as sns

# %%
plt.scatter(df.index,df['SepalWidthCm'])
plt.show()

# %%
sns.scatterplot(x=df.index,y=df['SepalWidthCm'],hue=df['Species'])

# %%
plt.figure(figsize=(6,6))
plt.title('Line plot of petal length')
plt.xlabel('index',fontsize=20)
plt.ylabel('petal length',fontsize=20)
plt.plot(df.index,df['PetalLengthCm'],markevery=1,marker='d')
for name,group in df.groupby('Species'):
  plt.plot(group.index,group['PetalLengthCm'], label=name,markevery=1,marker='d')
plt.legend()
plt.show()

# %%
#strip plot
sns.stripplot(y=df['SepalWidthCm'])

# %%
sns.stripplot(x=df['Species'],y=df['SepalWidthCm'])

# %%
#Swarm plot
sns.set(rc={'figure.figsize':(5,5)})
sns.swarmplot(x=df['SepalWidthCm'])

# %%
plt.hist(df['PetalWidthCm'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(5,5))
df['PetalLengthCm'].plot(kind='density')

# %%
#boxplot
plt.boxplot(df['SepalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8c54ff1fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8c550026d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8c54ff1c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8c55002d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8c5500c0d0>],
#  'means': []}

# %%
plt.figure(figsize=(15,10))
#Set Title
plt.title('Box plots of the 4 variables')
# plt.boxplot(df.values,labels=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
df.boxplot(column=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
